# %% [markdown]
# ## Examples for TimeSeriesValue and TimeSeries Classes

# %% [markdown]
# ### Setup

# %%
import os, sys

srcdir = os.path.join(os.path.dirname(os.getcwd()), "src")
sys.path.append(srcdir)
from hec.timeseries import TimeSeries
from hec.timeseries import TimeSeriesValue as TSV  # type: ignore
from hec.unit import UnitQuantity as UQ  # type: ignore
from hec.quality import Quality as Qual  # type: ignore
from hec.hectime import HecTime
from datetime import datetime
from datetime import timedelta
from datetime import timezone
import cwms, math

# %% [markdown]
# ### TimeSeriesValue Examples

# %%
tsv = TSV("14Oct2024 10:55", UQ(12.3, "ft"), Qual("okay"))
print(f"repr    = {repr(tsv)}")
print(f"str     = {tsv}")
print(f"time    = {tsv.time}")
print(f"value   = {tsv.value}")
print(f"quality = {tsv.quality.text}")
print("tsv.time += timedelta(minutes = 65)")
tsv.time += timedelta(minutes=65)
print("tsv.value += .7")
tsv.value += 0.7
print('tsv.quality = Qual("missing").setProtection(1)')
tsv.quality = Qual("missing").setProtection(1)
print(f"repr    = {repr(tsv)}")
print(f"str     = {tsv}")
print(f"time    = {tsv.time}")
print(f"value   = {tsv.value}")
print(f"quality = {tsv.quality.text}")
# Out:
# repr    = TimeSeriesValue(HecTime(UNDEFINED_TIME, MINUTE_GRANULARITY), UnitQuantity(12.3, 'ft'), Quality(3))
# str     = (, 12.3 ft, o)
# time    =
# value   = 12.3 ft
# quality = Unprotected Screened Okay No_Range Original None None None
# tsv.time += timedelta(minutes = 65)
# tsv.value += .7
# tsv.quality = Qual("missing").setProtection(1)
# repr    = TimeSeriesValue(HecTime(UNDEFINED_TIME, MINUTE_GRANULARITY), UnitQuantity(13.0, 'ft'), Quality(-2147483643))
# str     = (, 13.0 ft, M)
# time    =
# value   = 13.0 ft
# quality = Protected Screened Missing No_Range Original None None None

# %% [markdown]
# ### TimeSeries Examples

# %%
elev = TimeSeries(
    cwms.get_timeseries(
        ts_id="Keys.Elev.Inst.1Hour.0.Ccp-rev",
        office_id="SWT",
        unit="EN",
        begin=datetime.now(timezone.utc) - timedelta(hours=24),
    )
)
print(f"repr = {repr(elev)}")
print(f"str  = {elev}")
print(f"data = \n{elev.data}")
print("")
print(f"times     = {list(map(str, elev.times))}")
print(f"values    = {elev.values}")
print(f"qualities = {elev.qualities}")
start = str(elev.times[-10])
stop = str(elev.times[-4])
print(f"\nPython slicing: excludes {stop}")
print(elev[start:stop].data)
print(f"\nDataFrame slicing: includes {stop}")
elev.slice_stop_exclusive = False
print(elev[start:stop].data)
print(f"\nSlicing with step: get every other row")
print(elev[start:stop:2].data)
print("\nModify a value directly in DataFrame")
start = start.replace("T", " ")
elev.data.loc[start, "value"] = 1000
elev.data.loc[start, "quality"] = Qual("Questionable").code
print(elev[start:stop].data)
print("\nModify a value using API")
stop = stop.replace("T", " ")
elev.setValue(stop, math.nan)
elev.setQuality(stop, Qual("Missing"))
print(elev[start:stop].data)
# Out:
# repr = <TimeSeries(SWT/KEYS.Elev.Inst.1Hour.0.Ccp-Rev) unit=ft 24 values>
# str  = SWT/KEYS.Elev.Inst.1Hour.0.Ccp-Rev 24 vlaues in ft
# data =
#                             value  quality
# time
# 2024-10-16 23:00:00+00:00  718.53        0
# 2024-10-17 00:00:00+00:00  718.53        0
# 2024-10-17 01:00:00+00:00  718.53        0
# 2024-10-17 02:00:00+00:00  718.53        0
# 2024-10-17 03:00:00+00:00  718.53        0
# 2024-10-17 04:00:00+00:00  718.53        0
# 2024-10-17 05:00:00+00:00  718.53        0
# 2024-10-17 06:00:00+00:00  718.53        0
# 2024-10-17 07:00:00+00:00  718.53        0
# 2024-10-17 08:00:00+00:00  718.53        0
# 2024-10-17 09:00:00+00:00  718.52        0
# 2024-10-17 10:00:00+00:00  718.52        0
# 2024-10-17 11:00:00+00:00  718.53        0
# 2024-10-17 12:00:00+00:00  718.52        0
# 2024-10-17 13:00:00+00:00  718.53        0
# 2024-10-17 14:00:00+00:00  718.52        0
# 2024-10-17 15:00:00+00:00  718.53        0
# ...
