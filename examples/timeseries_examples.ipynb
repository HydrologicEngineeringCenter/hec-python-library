# %% [markdown]
# ## Examples for TimeSeriesValue and TimeSeries Classes

# %% [markdown]
# ### Setup

# %%
import os, sys

srcdir = os.path.join(os.path.dirname(os.getcwd()), "src")
sys.path.append(srcdir)
from hec.timeseries import TimeSeriesValue as TSV  # type: ignore
from hec.unit import UnitQuantity as UQ  # type: ignore
from hec.quality import Quality as Qual  # type: ignore
from datetime import timedelta

# %% [markdown]
# ### TimeSeriesValue Examples

# %%
tsv = TSV("14Oct2024 10:55", UQ(12.3, "ft"), Qual("okay"))
print(f"repr = {repr(tsv)}")
print(f"str  = {tsv}")
print("tsv.time += timedelta(minutes = 65)")
tsv.time += timedelta(minutes=65)
print("tsv.value += .7")
tsv.value += 0.7
print('tsv.quality = Qual("missing").setProtection(1)')
tsv.quality = Qual("missing").setProtection(1)
print(f"repr = {repr(tsv)}")
print(f"str  = {tsv}")
# Out:
# repr = TimeSeriesValue(HecTime([2024, 10, 14, 10, 55, 0], MINUTE_GRANULARITY), UnitQuantity(12.3, 'ft'), Quality(3))
# str  = (2024-10-14T10:55:00, 12.3 ft, o)
# tsv.time += timedelta(minutes = 65)
# tsv.value += .7
# tsv.quality = Qual("missing").setProtection(1)
# repr = TimeSeriesValue(HecTime([2024, 10, 14, 12, 0, 0], MINUTE_GRANULARITY), UnitQuantity(13.0, 'ft'), Quality(-2147483643))
# str  = (2024-10-14T12:00:00, 13.0 ft, M)
